# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import folium
from tslearn.clustering import TimeSeriesKMeans
from tslearn.utils import to_time_series_dataset
from tslearn.barycenters import dtw_barycenter_averaging
pd.set_option("display.max_rows", 101)
pd.set_option("display.max_columns", 101)
# %matplotlib inline
# Out:
# /Users/rmizuta/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.cluster.k_means_ module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.cluster. Anything that cannot be imported from sklearn.cluster is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df=pd.read_csv("../data/table2019.csv",encoding="cp932")

# %%
df[['年', '月', '日', '時（UTC）',"台風番号","緯度","経度"]].head(10)
# Out:
#       年   月   日  時（UTC）  台風番号   緯度     経度
# 0  2018  12  31       6  1901  7.6  111.9
# 1  2018  12  31      12  1901  7.3  111.3
# 2  2018  12  31      18  1901  7.0  111.1
# 3  2019   1   1       0  1901  6.6  110.7
# 4  2019   1   1       6  1901  6.3  110.2
# 5  2019   1   1      12  1901  6.0  109.9
# 6  2019   1   1      18  1901  5.8  109.5
# 7  2019   1   2       0  1901  5.9  108.6
# 8  2019   1   2       6  1901  6.2  108.0
# 9  2019   1   2      12  1901  6.3  107.0

# %%
map_osm = folium.Map(location=[35.6,139.7],zoom_start=3)
for num in df["台風番号"].unique():
    point=np.array(df[df["台風番号"]==num][["緯度","経度"]])
    folium.PolyLine(
            locations=point,                   
            ).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
points=[]
for num in df["台風番号"].unique():
    points.append(np.array(df[df["台風番号"]==num][["緯度","経度"]]))
points = to_time_series_dataset(points)

# %%
dba_km = TimeSeriesKMeans(n_clusters=3,
                          n_init=5,
                          metric="dtw",
                          verbose=True,
                          max_iter_barycenter=10,
                          random_state=22)

# %%
pred = dba_km.fit_predict(points)
# Out:
# Init 1
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# 6118.021 -->
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# 2515.883 --> 2357.304 -->
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# 2272.039 --> 2270.866 --> 2270.866 -->
# Init 2
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# 6181.621 -->
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 2935.324 --> 2847.295 --> 2847.295 -->
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# Init 3
# 6871.736 -->
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# 3198.289 --> 2808.471 -->
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# 2758.862 --> 2758.862 -->
# Init 4
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# 7391.380 -->
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# 3598.608 -->
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 2865.683 --> 2719.318 -->
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# 2719.318 -->
# Init 5
# 8401.362 -->
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# 3226.685 --> 3073.644 --> 3003.923 --> 3003.923 -->
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    0.0s finished

# %%
colors=["blue","yellow","green","red"]
c0=[]
c1=[]
c2=[]

map_osm = folium.Map(location=[35.6,139.7],zoom_start=3)
for num,c in zip(df["台風番号"].unique(),pred):
    if c==0:
        c0.append(np.array(df[df["台風番号"]==num][["緯度","経度"]]))
    elif c==1:
        c1.append(np.array(df[df["台風番号"]==num][["緯度","経度"]]))
    else:
        c2.append(np.array(df[df["台風番号"]==num][["緯度","経度"]]))
 
    point=np.array(df[df["台風番号"]==num][["緯度","経度"]])
    folium.PolyLine(
            locations=point,     
            color=colors[c],
            ).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#重心の計算
dba_c0=dtw_barycenter_averaging(c0)
dba_c1=dtw_barycenter_averaging(c1)
dba_c2=dtw_barycenter_averaging(c2)

folium.PolyLine(
            locations=dba_c0,     
            color=colors[3],
            ).add_to(map_osm)

folium.PolyLine(
            locations=dba_c1,     
            color=colors[3],
            ).add_to(map_osm)

folium.PolyLine(
            locations=dba_c2,     
            color=colors[3],
            ).add_to(map_osm)

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
